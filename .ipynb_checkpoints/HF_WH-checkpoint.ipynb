# %% [markdown]
# The project is divided into sections:
#
#     1- EDA (Exploratory Data Analysis)
#     2- Data Preprocessing
#         2.1 Dealing with Missing Values
#         2.2 Extract Target Feature
#         2.3 One hot encoding
#         2.4 Correlation
#         2.5 Feature Selection
#             2.5.1 eleminating features by the highly-Correlated features
#             2.5.2 Feature selection by estimating the importance of features using Extra Trees
#         2.6 Imbalanced Data (undersampling)
#     3- Modeling (3 models)
#         3.1 Train-Test split
#         3.2 Decision Tree
#         3.3 Random Forest
#         3.4 Adaboost
#     4- Evaluation
#         4.1 Accuracy
#         4.2 Recall

# %%
#import packages and scripts
from IPython.core.display import HTML
from string import Template
import pandas as pd
import os
import json, random
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
#get the d3 host remotely
HTML('<script src=https://d3js.org/d3.v4.min.js></script>')
# Out:
# <script src=https://d3js.org/d3.v4.min.js></script>

# %%
HTML('''<h1>Data Viz</h1>''')
# Out:
# <h1>Data Viz</h1>

# %%
os.getcwd()
# Out:
# '/Users/skydiver/Desktop/viz'

# %% [markdown]
# ### Data Exploratory

# %% [markdown]
# #### Human Freedom Dataset

# %%
#call data
hmn_frdm= pd.read_csv("hf.csv")

# %%
hmn_frdm.head()
# Out:
#    year ISO_code  countries                         region  pf_rol_procedural  \
# 0  2016      ALB    Albania                 Eastern Europe           6.661503
# 1  2016      DZA    Algeria     Middle East & North Africa                NaN
# 2  2016      AGO     Angola             Sub-Saharan Africa                NaN
# 3  2016      ARG  Argentina  Latin America & the Caribbean           7.098483
# 4  2016      ARM    Armenia        Caucasus & Central Asia                NaN
#
#    pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0      4.547244         4.666508  5.291752        8.920429
# 1           NaN              NaN  3.819566        9.456254
# 2           NaN              NaN  3.451814        8.060260
# 3      5.791960         4.343930  5.744791        7.622974
# 4           NaN              NaN  5.003205        8.808750
#
#    pf_ss_disappearances_disap     ...       ef_regulation_business_bribes  \
# 0                        10.0     ...                            4.050196
# 1                        10.0     ...                            3.765515
# 2                         5.0     ...                            1.945540
# 3                        10.0     ...                            3.260044
# 4                        10.0     ...                            4.575152
#
#    ef_regulation_business_licensing  ef_regulation_business_compliance  \
# 0                          7.324582                           7.074366
# 1                          8.523503                           7.029528
# 2                          8.096776                           6.782923
# 3                          5.253411                           6.508295
# 4                          9.319612                           6.491481
#
#    ef_regulation_business  ef_regulation  ef_score  ef_rank  hf_score  \
# 0                6.705863       6.906901      7.54     34.0  7.568140
# 1                5.676956       5.268992      4.99    159.0  5.135886
# 2                4.930271       5.518500      5.17    155.0  5.640662
# 3                5.535831       5.369019      4.84    160.0  6.469848
# 4                6.797530       7.378069      7.57     29.0  7.241402
#
#    hf_rank  hf_quartile
# 0     48.0          2.0
# 1    155.0          4.0
# 2    142.0          4.0
# 3    107.0          3.0
# 4     57.0          2.0
#
# [5 rows x 123 columns]

# %%
hmn_frdm.shape
# Out:
# (1458, 123)

# %%
hmn_frdm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Columns: 123 entries, year to hf_quartile
# dtypes: float64(119), int64(1), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# There are many columns in the dataset that prevented the function above to fetch it all

# %%
hmn_frdm.describe()
# Out:
#               year  pf_rol_procedural  pf_rol_civil  pf_rol_criminal  \
# count  1458.000000         880.000000    880.000000       880.000000
# mean   2012.000000           5.589355      5.474770         5.044070
# std       2.582875           2.080957      1.428494         1.724886
# min    2008.000000           0.000000      0.000000         0.000000
# 25%    2010.000000           4.133333      4.549550         3.789724
# 50%    2012.000000           5.300000      5.300000         4.575189
# 75%    2014.000000           7.389499      6.410975         6.400000
# max    2016.000000           9.700000      8.773533         8.719848
#
#             pf_rol  pf_ss_homicide  pf_ss_disappearances_disap  \
# count  1378.000000     1378.000000                 1369.000000
# mean      5.309641        7.412980                    8.341855
# std       1.529310        2.832947                    3.225902
# min       0.000000        0.000000                    0.000000
# 25%       4.131746        6.386978                   10.000000
# 50%       4.910797        8.638278                   10.000000
# 75%       6.513178        9.454402                   10.000000
# max       8.723094        9.926568                   10.000000
#
#        pf_ss_disappearances_violent  pf_ss_disappearances_organized  \
# count                   1378.000000                     1279.000000
# mean                       9.519458                        6.772869
# std                        1.744673                        2.768983
# min                        0.000000                        0.000000
# 25%                       10.000000                        5.000000
# 50%                       10.000000                        7.500000
# 75%                       10.000000                       10.000000
# max                       10.000000                       10.000000
#
#        pf_ss_disappearances_fatalities     ...       \
# count                      1378.000000     ...
# mean                          9.584972     ...
# std                           1.559826     ...
# min                           0.000000     ...
# 25%                           9.942607     ...
# 50%                          10.000000     ...
# 75%                          10.000000     ...
# max                          10.000000     ...
#
#        ef_regulation_business_bribes  ef_regulation_business_licensing  \
# count                    1283.000000                       1357.000000
# mean                        4.886192                          7.698494
# std                         1.889168                          1.728507
# min                         0.000000                          0.000000
# 25%                         3.433786                          6.874687
# 50%                         4.418371                          8.074161
# 75%                         6.227978                          8.991882
# max                         9.623811                          9.999638
#
#        ef_regulation_business_compliance  ef_regulation_business  \
# count                        1368.000000             1374.000000
# mean                            6.981858                6.317668
# std                             1.979200                1.230988
# min                             0.000000                2.009841
# 25%                             6.368178                5.591851
# 50%                             7.466692                6.265234
# 75%                             8.209310                7.139718
# max                             9.865488                9.272600
#
#        ef_regulation     ef_score      ef_rank     hf_score      hf_rank  \
# count    1378.000000  1378.000000  1378.000000  1378.000000  1378.000000
# mean        7.019782     6.785610    76.973149     6.993444    77.007983
# std         1.027625     0.883601    44.540142     1.025811    44.506549
# min         2.483540     2.880000     1.000000     3.765827     1.000000
# 25%         6.429498     6.250000    38.000000     6.336685    39.000000
# 50%         7.082075     6.900000    77.000000     6.923840    76.000000
# 75%         7.720955     7.410000   115.000000     7.894660   115.000000
# max         9.439828     9.190000   162.000000     9.126313   162.000000
#
#        hf_quartile
# count  1378.000000
# mean      2.490566
# std       1.119698
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       4.000000
#
# [8 rows x 120 columns]

# %% [markdown]
# from above the dataset covers data from year 2008 to 2016

# %%
#select only numerical data from the data frame and check the distribution
df_num = hmn_frdm.select_dtypes(include = ['float64', 'int64'])
#df_num.head()
# We will explore the the distribution of the numerical data in the data set
df_num.hist(figsize=(50, 50), bins=50, xlabelsize=3, ylabelsize=3);

# %% [markdown]
# ##### Preprocessing

# %%
hmn_frdm.columns
# Out:
# Index(['year', 'ISO_code', 'countries', 'region', 'pf_rol_procedural',
#        'pf_rol_civil', 'pf_rol_criminal', 'pf_rol', 'pf_ss_homicide',
#        'pf_ss_disappearances_disap',
#        ...
#        'ef_regulation_business_bribes', 'ef_regulation_business_licensing',
#        'ef_regulation_business_compliance', 'ef_regulation_business',
#        'ef_regulation', 'ef_score', 'ef_rank', 'hf_score', 'hf_rank',
#        'hf_quartile'],
#       dtype='object', length=123)

# %%
#check the percentatage of NAs in every column
na = hmn_frdm.isnull().sum()/len(hmn_frdm)
#filter columns with NA above 0.3 of the data
na_3 = na[na>0.3]
#delete columns with NA above 0.3 of the data
for ind in na_3.index:
    del hmn_frdm[ind]
    #double check if NAs were removed
na_after = hmn_frdm.isnull().sum()/len(hmn_frdm)
#check if there are still columns with NA above 0.3 of the data
na_after_3 = na_after[na_after>0.3]
na_after_3.index
# Out:
# Index([], dtype='object')

# %%
hmn_frdm.shape
# Out:
# (1458, 106)

# %%
(hmn_frdm.mean())
# Out:
# year                                  2012.000000
# pf_rol                                   5.309641
# pf_ss_homicide                           7.412980
# pf_ss_disappearances_disap               8.341855
# pf_ss_disappearances_violent             9.519458
# pf_ss_disappearances_organized           6.772869
# pf_ss_disappearances_fatalities          9.584972
# pf_ss_disappearances_injuries            9.598734
# pf_ss_disappearances                     8.811573
# pf_ss_women_fgm                          9.237247
# pf_ss_women_missing                      9.125561
# pf_ss_women_inheritance                  6.635549
# pf_ss_women                              8.331701
# pf_ss                                    8.181087
# pf_movement_domestic                     7.702206
# pf_movement_foreign                      7.676471
# pf_movement_women                        8.044799
# pf_movement                              7.823537
# pf_religion_estop                        7.448701
# pf_religion_harassment                   8.781535
# pf_religion_restrictions                 7.298053
# pf_religion                              7.875138
# pf_association_association               7.825509
# pf_association_assembly                  7.418069
# pf_association_political                 6.915781
# pf_association_prof                      7.002510
# pf_association_sport                     7.803735
# pf_association                           7.424343
# pf_expression_killed                     9.230763
# pf_expression_jailed                     9.656823
#                                          ...
# ef_trade_black                           9.767210
# ef_trade_movement_foreign                5.929957
# ef_trade_movement_capital                3.583793
# ef_trade_movement_visit                  5.352696
# ef_trade_movement                        4.882894
# ef_trade                                 7.053594
# ef_regulation_credit_ownership           7.699844
# ef_regulation_credit_private             7.898674
# ef_regulation_credit_interest            9.330633
# ef_regulation_credit                     8.313702
# ef_regulation_labor_minwage              6.446196
# ef_regulation_labor_firing               4.741065
# ef_regulation_labor_bargain              6.436956
# ef_regulation_labor_hours                7.962044
# ef_regulation_labor_dismissal            6.459588
# ef_regulation_labor_conscription         6.554829
# ef_regulation_labor                      6.439643
# ef_regulation_business_adm               3.971425
# ef_regulation_business_bureaucracy       5.271015
# ef_regulation_business_start             8.853396
# ef_regulation_business_bribes            4.886192
# ef_regulation_business_licensing         7.698494
# ef_regulation_business_compliance        6.981858
# ef_regulation_business                   6.317668
# ef_regulation                            7.019782
# ef_score                                 6.785610
# ef_rank                                 76.973149
# hf_score                                 6.993444
# hf_rank                                 77.007983
# hf_quartile                              2.490566
# dtype: float64

# %% [markdown]
# the number of columns shrinked to 106 columns, I will now fill the NAs of the rest of the columns with less than 0.3 NAs

# %%
#fill NA with mean value
hf_df_new = hmn_frdm.fillna(hmn_frdm.mean(),axis=0)
hf_df_new.isnull().sum()
# Out:
# year                                  0
# ISO_code                              0
# countries                             0
# region                                0
# pf_rol                                0
# pf_ss_homicide                        0
# pf_ss_disappearances_disap            0
# pf_ss_disappearances_violent          0
# pf_ss_disappearances_organized        0
# pf_ss_disappearances_fatalities       0
# pf_ss_disappearances_injuries         0
# pf_ss_disappearances                  0
# pf_ss_women_fgm                       0
# pf_ss_women_missing                   0
# pf_ss_women_inheritance               0
# pf_ss_women                           0
# pf_ss                                 0
# pf_movement_domestic                  0
# pf_movement_foreign                   0
# pf_movement_women                     0
# pf_movement                           0
# pf_religion_estop                     0
# pf_religion_harassment                0
# pf_religion_restrictions              0
# pf_religion                           0
# pf_association_association            0
# pf_association_assembly               0
# pf_association_political              0
# pf_association_prof                   0
# pf_association_sport                  0
#                                      ..
# ef_trade_black                        0
# ef_trade_movement_foreign             0
# ef_trade_movement_capital             0
# ef_trade_movement_visit               0
# ef_trade_movement                     0
# ef_trade                              0
# ef_regulation_credit_ownership        0
# ef_regulation_credit_private          0
# ef_regulation_credit_interest         0
# ef_regulation_credit                  0
# ef_regulation_labor_minwage           0
# ef_regulation_labor_firing            0
# ef_regulation_labor_bargain           0
# ef_regulation_labor_hours             0
# ef_regulation_labor_dismissal         0
# ef_regulation_labor_conscription      0
# ef_regulation_labor                   0
# ef_regulation_business_adm            0
# ef_regulation_business_bureaucracy    0
# ef_regulation_business_start          0
# ef_regulation_business_bribes         0
# ef_regulation_business_licensing      0
# ef_regulation_business_compliance     0
# ef_regulation_business                0
# ef_regulation                         0
# ef_score                              0
# ef_rank                               0
# hf_score                              0
# hf_rank                               0
# hf_quartile                           0
# dtype: int64

# %%
hf_df_new.head()
# Out:
#    year ISO_code  countries                         region    pf_rol  \
# 0  2016      ALB    Albania                 Eastern Europe  5.291752
# 1  2016      DZA    Algeria     Middle East & North Africa  3.819566
# 2  2016      AGO     Angola             Sub-Saharan Africa  3.451814
# 3  2016      ARG  Argentina  Latin America & the Caribbean  5.744791
# 4  2016      ARM    Armenia        Caucasus & Central Asia  5.003205
#
#    pf_ss_homicide  pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# 0        8.920429                        10.0                      10.00000
# 1        9.456254                        10.0                       9.29403
# 2        8.060260                         5.0                      10.00000
# 3        7.622974                        10.0                      10.00000
# 4        8.808750                        10.0                      10.00000
#
#    pf_ss_disappearances_organized  pf_ss_disappearances_fatalities  ...    \
# 0                            10.0                        10.000000  ...
# 1                             5.0                         9.926119  ...
# 2                             7.5                        10.000000  ...
# 3                             7.5                        10.000000  ...
# 4                             7.5                         9.316196  ...
#
#    ef_regulation_business_licensing  ef_regulation_business_compliance  \
# 0                          7.324582                           7.074366
# 1                          8.523503                           7.029528
# 2                          8.096776                           6.782923
# 3                          5.253411                           6.508295
# 4                          9.319612                           6.491481
#
#    ef_regulation_business  ef_regulation  ef_score  ef_rank  hf_score  \
# 0                6.705863       6.906901      7.54     34.0  7.568140
# 1                5.676956       5.268992      4.99    159.0  5.135886
# 2                4.930271       5.518500      5.17    155.0  5.640662
# 3                5.535831       5.369019      4.84    160.0  6.469848
# 4                6.797530       7.378069      7.57     29.0  7.241402
#
#    hf_rank  hf_quartile  class
# 0     48.0          2.0    Med
# 1    155.0          4.0    Med
# 2    142.0          4.0    Med
# 3    107.0          3.0    Med
# 4     57.0          2.0    Med
#
# [5 rows x 107 columns]

# %% [markdown]
# next I will divide class to high, medium and low

# %%
#derive a new column that divides countries to high(>7.5), medium(4-7.5) and low(<4) level of human freedom based on hf_score
import numpy as np
hf_df_new['class_high'] = np.where(hf_df_new['hf_score']>7.5 , "High",0)
hf_df_new['class_low'] = np.where(hf_df_new['hf_score']<4 , "Low",0)
hf_df_new['AllTogether'] = hf_df_new['class_high'].str.cat(hf_df_new['class_low'], sep=' - ')
hf_df_new.head(10)
hf_df_new = hf_df_new.replace(['0 - 0', 'High - 0','0 - Low'], 
                     ['Med','High','Low']) 
hf_df_new['AllTogether'].value_counts()

# %% [markdown]
# #### world happiness Dataset

# %%
#call data
wrld_hpns=pd.read_csv("wh.csv")

# %%
wrld_hpns.head()

# %%
wrld_hpns.shape()

# %%
wrld_hpns.info()

# %%
wrld_hpns.describe()

# %%
#select only numerical data from the data frame and check the distribution
wh_num = wrld_hpns.select_dtypes(include = ['float64', 'int64'])
#df_num.head()
# We will explore the the distribution of the numerical data in the data set
wh_num.hist(figsize=(50, 50), bins=50, xlabelsize=3, ylabelsize=3);

# %%
wh_num.columns

# %%
#check the percentatage of NAs in every column
na_wh = wh_num.isnull().sum()/len(wh_num)
#filter columns with NA above 0.3 of the data
na_wh_3 = na_wh[na_wh>0.3]
#delete columns with NA above 0.3 of the data
for ind in na_wh_3.index:
    del wh_num[ind]
    #double check if NAs were removed
wh_na_after = wh_num.isnull().sum()/len(wh_num)
#check if there are still columns with NA above 0.3 of the data
wh_na_after_3 = wh_na_after[wh_na_after>0.3]
wh_na_after_3.index

# %%
wh_num.shape

# %%
(wh_num.mean())

# %%
#fill NA with mean value
wh_df_new = wh_num.fillna(wh_num.mean(),axis=0)
wh_df_new.isnull().sum()

# %%
wh_df_new.head()
